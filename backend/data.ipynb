# %%
import json
def add_source_to_existing_json(qa_list):
    # 출처 매핑 테이블
    source_map = [
        (1, 20, "https://terms.naver.com/entry.naver?docId=3569533&cid=59015&categoryId=59015"),
        (21, 40, "https://terms.naver.com/entry.naver?docId=5707247&cid=43667&categoryId=43667"),
        (41, 70, "https://encykorea.aks.ac.kr/Article/E0029857"),
        (71, 90, "https://encykorea.aks.ac.kr/Article/E0065805"),
        (91, 105, "https://encykorea.aks.ac.kr/Article/E0048697"),
        (106, 125, "https://encykorea.aks.ac.kr/Article/E0065420"),
        (126, 145, "https://encykorea.aks.ac.kr/Article/E0029365"),
        (146, 165, "https://encykorea.aks.ac.kr/Article/E0055081")
    ]

    result = []
    for idx, qa in enumerate(qa_list, start=1):
        # 출처 URL 매핑
        source = next((url for start, end, url in source_map if start <= idx <= end), "출처 없음")

        # 기존 QA에 번호와 출처 추가
        enriched = {
            "number": idx,
            "question": qa["question"],
            "answer": qa["answer"],
            "source": source
        }
        result.append(enriched)

    return result


# 파일에서 읽기
with open('data.json', 'r', encoding='utf-8') as f:
    qa_list = json.load(f)

# 위 함수 적용
updated = add_source_to_existing_json(qa_list)

# 저장
with open('qa_with_source.json', 'w', encoding='utf-8') as f:
    json.dump(updated, f, ensure_ascii=False, indent=2)

# ✅ 실행

updated_qa_list = add_source_to_existing_json(qa_list)

# ✅ 결과 출력
print(json.dumps(updated_qa_list, indent=2, ensure_ascii=False))
# Out:
# [
#   {
#     "number": 1,
#     "question": "세종대왕은 어떤 인물인가요?",
#     "answer": "세종대왕은 조선의 제4대 왕으로, 한글을 창제하고 유교 정치와 민족문화를 꽃피운 인물입니다. 당대에는 '해동요순'이라 불릴 만큼 존경받았으며, 지금까지도 가장 위대한 왕 중 하나로 평가받습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=3569533&cid=59015&categoryId=59015"
#   },
#   {
#     "number": 2,
#     "question": "세종대왕은 어떤 호칭으로 불렸나요?",
#     "answer": "세종대왕은 '성군', '대왕'이라는 호칭으로 불렸고, 당대에는 '해동요순'이라는 이상적 성군의 대명사로도 칭해졌습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=3569533&cid=59015&categoryId=59015"
#   },
#   {
#     "number": 3,
#     "question": "세종대왕의 본명과 자는 무엇인가요?",
#     "answer": "세종대왕의 이름은 이도(李祹)이며, 자는 원정(元正)입니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=3569533&cid=59015&categoryId=59015"
#   },
#   {
#     "number": 4,
#     "question": "세종대왕의 즉위 과정은 어땠나요?",
#     "answer": "세종은 셋째 아들이었지만, 태종이 세자 이제를 폐위하고 충녕대군이었던 세종을 세자로 책봉하며 왕위에 올랐습니다. 태종은 총명하고 학문을 좋아한 세종의 자질을 높이 평가했습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=3569533&cid=59015&categoryId=59015"
#   },
#   {
#     "number": 5,
#     "question": "즉위 초기에 세종은 어떤 어려움을 겪었나요?",
#     "answer": "즉위 초 세종은 경험 부족과 상왕 태종의 영향력 속에서 '상왕의 뜻이 이러하다'는 말을 자주 해야 했고, 정치적으로 어려운 입장이었습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=3569533&cid=59015&categoryId=59015"
#   },
#   {
#     "number": 6,
#     "question": "세종대왕은 어떤 학문적 특징을 가졌나요?",
#     "answer": "세종은 유학뿐만 아니라 역사, 천문, 음악, 의학 등 다방면에 능통한 호학 군주였으며, 독서와 지식 정리에 뛰어났습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=3569533&cid=59015&categoryId=59015"
#   },
#   {
#     "number": 7,
#     "question": "세종은 어떤 방식으로 제도를 만들었나요?",
#     "answer": "세종은 유학의 경전과 사서를 연구해 이상적인 제도를 분석하고, 역사적 배경과 실효성을 고려해 구체적인 제도를 만들었습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=3569533&cid=59015&categoryId=59015"
#   },
#   {
#     "number": 8,
#     "question": "세종대왕은 어떤 역사서를 정비했나요?",
#     "answer": "세종은 고려사, 고려사절요 등을 정비하고, 중국 역사서 자치통감을 주석하여 자치통감훈의를 편찬하게 했습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=3569533&cid=59015&categoryId=59015"
#   },
#   {
#     "number": 9,
#     "question": "세종 시기에 인쇄술은 어떻게 발전했나요?",
#     "answer": "많은 자료를 간행하려는 노력 덕분에 세종대왕 시대에는 인쇄 속도가 10배 이상 발전했습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=3569533&cid=59015&categoryId=59015"
#   },
#   {
#     "number": 10,
#     "question": "집현전은 세종대왕 시대에 어떤 역할을 했나요?",
#     "answer": "집현전은 세종의 학문과 제도 개혁을 지원하는 연구기관으로, 정인지, 성삼문, 신숙주 등이 다양한 분야의 연구를 맡았습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=3569533&cid=59015&categoryId=59015"
#   },
#   {
#     "number": 11,
#     "question": "세종대왕이 관심을 가졌던 과학기술은 무엇인가요?",
#     "answer": "세종은 서운관을 설치해 천문학을 연구하고, 혼천의, 자격루, 앙부일구 등 백성을 위한 과학기구들을 제작했습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=3569533&cid=59015&categoryId=59015"
#   },
#   {
#     "number": 12,
#     "question": "세종은 음악 분야에서도 어떤 업적을 남겼나요?",
#     "answer": "세종은 박연을 통해 아악을 정비하고, 맹사성을 통해 향악을 발전시켜 조선에 적합한 음악 체계를 만들었습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=3569533&cid=59015&categoryId=59015"
#   },
#   {
#     "number": 13,
#     "question": "세종대왕의 애민정신은 어떻게 나타났나요?",
#     "answer": "세종은 자주 사면령을 내리고, 노비 처우 개선, 출산휴가 연장 등 백성을 배려하는 정책을 펼쳐 애민군주로 평가받습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=3569533&cid=59015&categoryId=59015"
#   },
#   {
#     "number": 14,
#     "question": "훈민정음 창제 목적은 무엇인가요?",
#     "answer": "백성이 쉽게 글을 배우고 범죄를 피할 수 있도록, 기존 한자 대신 이해하기 쉬운 문자체계를 만들기 위해 훈민정음을 창제했습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=3569533&cid=59015&categoryId=59015"
#   },
#   {
#     "number": 15,
#     "question": "훈민정음 창제와 관련된 기록은 왜 적은가요?",
#     "answer": "훈민정음은 비밀리에 창제된 것으로 보이며, 반발을 의식한 세종이 창제 과정을 공개하지 않아 관련 기록이 많지 않습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=3569533&cid=59015&categoryId=59015"
#   },
#   {
#     "number": 16,
#     "question": "훈민정음 창제에 집현전 학자들이 관여했나요?",
#     "answer": "정확한 참여 여부는 불확실하지만, 정인지가 훈민정음 서문을 쓴 점과 당시 학문 환경으로 미루어 공동 작업일 가능성도 있습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=3569533&cid=59015&categoryId=59015"
#   },
#   {
#     "number": 17,
#     "question": "세종대왕은 어떤 병을 앓았나요?",
#     "answer": "세종은 30대 초부터 풍질을 앓기 시작했고, 40대에는 앉아서 정사를 보기 어려울 정도로 건강이 악화되었습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=3569533&cid=59015&categoryId=59015"
#   },
#   {
#     "number": 18,
#     "question": "세종은 후반기에 어떤 정치적 조치를 했나요?",
#     "answer": "건강상의 이유로 의정부 서사제로 전환하고 세자에게 정무를 위임하여, 권력을 분산시키는 유교적 왕도 정치를 실현했습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=3569533&cid=59015&categoryId=59015"
#   },
#   {
#     "number": 19,
#     "question": "세종대왕은 언제 세상을 떠났나요?",
#     "answer": "세종은 1450년, 54세의 나이로 세상을 떠났습니다. 많은 병을 앓으면서도 마지막까지 정사를 돌보았습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=3569533&cid=59015&categoryId=59015"
#   },
#   {
#     "number": 20,
#     "question": "세종대왕의 능은 어디에 있나요?",
#     "answer": "세종대왕의 능은 경기도 여주시 영릉에 있으며, 정비 소헌왕후와 함께 합장되어 있습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=3569533&cid=59015&categoryId=59015"
#   },
#   {
#     "number": 21,
#     "question": "세종대왕은 언제부터 언제까지 재위했나요?",
#     "answer": "세종대왕은 1418년에 즉위하여 1450년까지 약 32년간 재위했습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=5707247&cid=43667&categoryId=43667"
#   },
#   {
#     "number": 22,
#     "question": "세종대왕은 몇 대 왕인가요?",
#     "answer": "세종대왕은 조선의 제4대 왕입니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=5707247&cid=43667&categoryId=43667"
#   },
#   {
#     "number": 23,
#     "question": "세종대왕의 출생과 사망 연도는?",
#     "answer": "세종대왕은 1397년에 태어나 1450년에 서거했습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=5707247&cid=43667&categoryId=43667"
#   },
#   {
#     "number": 24,
#     "question": "세종대왕의 왕비는 누구였나요?",
#     "answer": "세종대왕의 왕비는 소헌왕후 심씨입니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=5707247&cid=43667&categoryId=43667"
#   },
#   {
#     "number": 25,
#     "question": "세종대왕의 능은 어디에 있나요?",
#     "answer": "세종대왕은 경기도 여주시 능서면에 있는 영릉(英陵)에 묻혀 있습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=5707247&cid=43667&categoryId=43667"
#   },
#   {
#     "number": 26,
#     "question": "세종은 어떤 정치체제를 실시했나요?",
#     "answer": "세종은 의정부서사제를 시행하여 재상이 정치를 주도하고, 왕은 군사와 인사에 집중하는 방식으로 왕권과 신권의 조화를 이루었습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=5707247&cid=43667&categoryId=43667"
#   },
#   {
#     "number": 27,
#     "question": "집현전은 언제 설치되었나요?",
#     "answer": "집현전은 1420년에 설치되어 왕립 학술기관으로 기능했습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=5707247&cid=43667&categoryId=43667"
#   },
#   {
#     "number": 28,
#     "question": "훈민정음은 언제 창제되고 반포되었나요?",
#     "answer": "훈민정음은 1443년에 창제되어, 1446년에 반포되었습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=5707247&cid=43667&categoryId=43667"
#   },
#   {
#     "number": 29,
#     "question": "세종대왕이 장려한 한글 문헌에는 어떤 것들이 있나요?",
#     "answer": "세종은 한글로 용비어천가, 석보상절, 월인천강지곡 등을 편찬하며 보급을 장려했습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=5707247&cid=43667&categoryId=43667"
#   },
#   {
#     "number": 30,
#     "question": "세종은 음악 분야에서 어떤 조치를 했나요?",
#     "answer": "세종은 1425년 관습도감을 설치하고 박연에게 아악을 정리하도록 했습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=5707247&cid=43667&categoryId=43667"
#   },
#   {
#     "number": 31,
#     "question": "세종 시기 주요 과학기술 발명품은 무엇인가요?",
#     "answer": "세종 시기에는 측우기, 혼천의, 앙부일구, 자격루 등이 발명되어 천문과 시간 측정에 활용되었습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=5707247&cid=43667&categoryId=43667"
#   },
#   {
#     "number": 32,
#     "question": "칠정산은 무엇인가요?",
#     "answer": "칠정산은 조선의 독자적인 역법으로, 내편과 외편으로 구성되어 기존 중국 역법의 의존을 벗어나기 위해 편찬되었습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=5707247&cid=43667&categoryId=43667"
#   },
#   {
#     "number": 33,
#     "question": "세종대왕이 시행한 조세 제도는?",
#     "answer": "세종은 연분 9등법과 전분 6등법을 시행하여 조세의 공정성과 효율성을 높였습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=5707247&cid=43667&categoryId=43667"
#   },
#   {
#     "number": 34,
#     "question": "세종은 민생 안정에 어떤 노력을 했나요?",
#     "answer": "세종은 의창 운영, 의료제도 개선, 사형 삼심제(금부삼복법)를 통해 백성의 삶을 안정시키려 했습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=5707247&cid=43667&categoryId=43667"
#   },
#   {
#     "number": 35,
#     "question": "세종대왕의 대외 정책은 무엇이 있었나요?",
#     "answer": "세종은 여진족을 몰아내고 4군6진을 개척하고, 일본과는 쓰시마 정벌과 함께 3포 개항, 계해약조를 맺는 회유책을 병행했습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=5707247&cid=43667&categoryId=43667"
#   },
#   {
#     "number": 36,
#     "question": "4군 6진 개척의 목적은 무엇이었나요?",
#     "answer": "세종은 여진족의 침입을 막기 위해 압록강과 두만강 유역에 4군 6진을 설치하여 국경선을 확정하고 방어 거점을 마련했습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=5707247&cid=43667&categoryId=43667"
#   },
#   {
#     "number": 37,
#     "question": "대마도 정벌은 왜 일어났나요?",
#     "answer": "대마도 정벌은 1419년 세종이 왜구의 해안 약탈을 근절하기 위해 이종무를 파견해 수행한 군사 작전입니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=5707247&cid=43667&categoryId=43667"
#   },
#   {
#     "number": 38,
#     "question": "장영실은 어떤 업적을 남겼나요?",
#     "answer": "장영실은 측우기, 자격루, 수표 등 다양한 과학기구를 발명한 궁중 기술자였으며, 본래 관노 출신이었으나 면천되어 활동했습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=5707247&cid=43667&categoryId=43667"
#   },
#   {
#     "number": 39,
#     "question": "황희는 어떤 인물이었나요?",
#     "answer": "황희는 세종의 재상으로 오랫동안 좌의정을 지냈고, 청렴하고 온화한 인품으로 백성들에게 존경받았습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=5707247&cid=43667&categoryId=43667"
#   },
#   {
#     "number": 40,
#     "question": "맹사성은 어떤 업적을 남겼나요?",
#     "answer": "맹사성은 시문과 음악에 능한 명재상으로, 예문관 대제학과 우의정을 지내며 향악 정비와 악기 제작에 기여했습니다.",
#     "source": "https://terms.naver.com/entry.naver?docId=5707247&cid=43667&categoryId=43667"
#   },
#   {
#     "number": 41,
#     "question": "세종대왕은 어떻게 즉위하게 되었나요?",
#     "answer": "원래 세자는 양녕대군이었으나 품위를 손상시키는 일련의 행동으로 인해 폐위되었고, 태종은 셋째 아들인 충녕대군을 1418년 6월 왕세자로 책봉한 뒤, 같은 해 8월에 양위하여 세종이 왕위에 오르게 되었습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029857"
#   },
#   {
#     "number": 42,
#     "question": "세종 즉위 초기의 정치 상황은 어땠나요?",
#     "answer": "즉위 초기 세종은 상왕 태종의 정치적 영향 아래 있었으며, 세종 4년까지는 태종이 국정에 상당한 영향력을 행사했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029857"
#   },
#   {
#     "number": 43,
#     "question": "세종은 유교 정치 실현을 위해 어떤 기틀을 마련했나요?",
#     "answer": "세종은 집현전을 통해 인재를 양성하고, 유교적 의례와 제도를 정비했으며, 방대한 편찬사업을 통해 유교정치의 기반을 다졌습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029857"
#   },
#   {
#     "number": 44,
#     "question": "육조직계제와 의정부서사제의 차이는 무엇인가요?",
#     "answer": "육조직계제는 왕이 각 부서에 직접 명령을 내리는 체제로 왕권이 강했으며, 의정부서사제는 재상이 먼저 의논하고 왕이 결정하는 방식으로 신권과 조화를 이루는 체제였습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029857"
#   },
#   {
#     "number": 45,
#     "question": "집현전은 세종 시대에 어떤 역할을 했나요?",
#     "answer": "집현전은 학문 진흥과 정책 연구를 위한 기관으로, 많은 인재를 배출하고 편찬사업과 유교적 제도 정비에 핵심적인 역할을 했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029857"
#   },
#   {
#     "number": 46,
#     "question": "세종은 유교적 의례 정비에서 어떤 태도를 취했나요?",
#     "answer": "세종은 중국의 제도를 그대로 따르기보다, 조선 실정에 맞게 비판하고 수정하여 주체성을 유지하려 노력했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029857"
#   },
#   {
#     "number": 47,
#     "question": "세종대의 편찬사업에는 어떤 책들이 있었나요?",
#     "answer": "훈민정음, 농사직설, 의방유취, 고려사, 자치통감훈의, 동국정운, 삼강행실도, 향약집성방 등 다양한 분야의 책이 편찬되었습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029857"
#   },
#   {
#     "number": 48,
#     "question": "훈민정음은 어떤 배경에서 창제되었나요?",
#     "answer": "세종은 백성이 한자를 익히기 어려워 불편함을 겪는 것을 안타깝게 여겨, 집현전 학자들과 함께 백성을 위한 문자체계를 만들고자 훈민정음을 창제했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029857"
#   },
#   {
#     "number": 49,
#     "question": "훈민정음 창제에 참여한 학자들은 누구인가요?",
#     "answer": "최항, 박팽년, 성삼문, 신숙주, 이개, 이선로 등이 훈민정음 창제에 협력한 집현전 학자들입니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029857"
#   },
#   {
#     "number": 50,
#     "question": "세종 시대 천문학의 성과는 무엇인가요?",
#     "answer": "세종은 혼천의, 혼상, 정방안, 간의대 등을 설치하고 천문 관측을 체계화했으며, 천문역법서인 칠정산 내편·외편, 제가역상집을 편찬하게 했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029857"
#   },
#   {
#     "number": 51,
#     "question": "앙부일구는 어떤 해시계인가요?",
#     "answer": "앙부일구는 백성들을 위해 거리 곳곳에 설치된 공중용 해시계로, 우리나라 최초의 공중시계였습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029857"
#   },
#   {
#     "number": 52,
#     "question": "세종 시대의 대표적인 물시계는 무엇인가요?",
#     "answer": "자격루는 세종이 장영실에게 제작을 맡겨 만든 자동시보 물시계로, 경복궁 남쪽 보루각에 설치되었습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029857"
#   },
#   {
#     "number": 53,
#     "question": "세종은 도량형 제도를 어떻게 정비했나요?",
#     "answer": "세종은 황종율이 나오는 황종관을 기준으로 삼아 자와 무게의 단위를 설정하였으며, 이 기준은 후에 경국대전에 법제화되었습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029857"
#   },
#   {
#     "number": 54,
#     "question": "세종 시대의 대표적인 금속활자는 무엇인가요?",
#     "answer": "경자자, 갑인자, 병진자 등 정교한 금속활자가 주조되었고, 인쇄술은 크게 발전하였습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029857"
#   },
#   {
#     "number": 55,
#     "question": "총통등록은 어떤 책인가요?",
#     "answer": "총통등록은 화포의 제작법, 화약 사용법, 화포의 규격 등을 그림과 함께 설명한 책으로, 조선의 무기 발전에 중요한 업적입니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029857"
#   },
#   {
#     "number": 56,
#     "question": "농사직설은 어떤 책인가요?",
#     "answer": "정초가 저술한 농사직설은 조선의 실정에 맞는 농업 기술을 담은 농서로, 실용적 농업 기술 전파에 중요한 역할을 했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029857"
#   },
#   {
#     "number": 57,
#     "question": "세종이 편찬한 의약서는 어떤 것이 있나요?",
#     "answer": "향약집성방, 의방유취 등은 한방 의학과 민간 요법을 체계화한 의약서로, 조선 의학 발전에 큰 기여를 했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029857"
#   },
#   {
#     "number": 58,
#     "question": "정간보는 어떤 기보법인가요?",
#     "answer": "정간보는 음의 길이(시가)와 박자를 정간으로 표시할 수 있는 기보법으로, 현재도 국악 악보에 사용됩니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029857"
#   },
#   {
#     "number": 59,
#     "question": "세종이 작곡한 곡에는 무엇이 있나요?",
#     "answer": "정대업, 보태평, 봉래의 등 대곡을 작곡했으며, 여민락도 세종이 작곡한 음악입니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029857"
#   },
#   {
#     "number": 60,
#     "question": "세종 시대의 법제 정비 중 대표적인 것은?",
#     "answer": "속육전과 신찬경제속육전 등의 법전 편찬, 삼복법 도입, 옥사 인권 보호, 수금 대상 연령 제한 등이 있습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029857"
#   },
#   {
#     "number": 61,
#     "question": "공법은 어떤 제도인가요?",
#     "answer": "공법은 전세 제도를 개편하여 연분 9등법, 전분 6등법, 결부법을 통해 조세를 합리화한 세종 시대의 조세제도입니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029857"
#   },
#   {
#     "number": 62,
#     "question": "4군 6진 개척의 의의는 무엇인가요?",
#     "answer": "4군 6진의 개척은 여진족을 몰아내고 압록강과 두만강 이남을 영토로 편입하여 북방 국경선을 확정하는 데 큰 역할을 했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029857"
#   },
#   {
#     "number": 63,
#     "question": "세종은 왜 대마도를 정벌했나요?",
#     "answer": "왜구의 침입을 근절하기 위해 1419년 이종무를 파견하여 대마도 정벌을 단행했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029857"
#   },
#   {
#     "number": 64,
#     "question": "세종의 불교 정책은 어땠나요?",
#     "answer": "유교적 기반 하에 불교 권한을 축소하려 했으나, 말년에는 가족의 죽음과 건강 악화로 불교를 허용하고 내불당을 세우는 등 변화된 태도를 보였습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029857"
#   },
#   {
#     "number": 65,
#     "question": "세종은 어떤 인성의 왕이었나요?",
#     "answer": "세종은 유교적 소양과 주체성, 통찰력, 민본주의 정신을 가진 왕으로, 인재를 존중하고 인정을 베푸는 성군으로 평가받습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029857"
#   },
#   {
#     "number": 66,
#     "question": "세종은 사료 관리에 어떤 제도를 도입했나요?",
#     "answer": "전주사고, 성주사고 등 사고를 늘려 실록 보존 체계를 강화하여 조선 전기 실록이 후대에 전해지게 했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029857"
#   },
#   {
#     "number": 67,
#     "question": "세종의 묘호와 시호는 무엇인가요?",
#     "answer": "묘호는 세종(世宗), 시호는 장헌영문예무인성명효대왕(莊憲英文睿武仁聖明孝大王)입니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029857"
#   },
#   {
#     "number": 68,
#     "question": "세종의 업적이 남긴 역사적 의의는?",
#     "answer": "세종대는 정치적 안정, 학문과 문화의 진흥, 과학기술의 발전을 이룬 조선의 르네상스기로 평가받으며, 세종의 인성과 통치 철학이 그 기반이었습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029857"
#   },
#   {
#     "number": 69,
#     "question": "세종은 왜 한국사에서 특별히 존경받는 왕인가요?",
#     "answer": "세종은 유교적 이상 정치를 실현하고, 한글 창제를 통해 백성 중심의 문화를 열었으며, 정치·과학·문화의 총합적 발전을 이끈 성군으로 존경받습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029857"
#   },
#   {
#     "number": 70,
#     "question": "훈민정음 해례본은 무엇인가요?",
#     "answer": "훈민정음 해례본은 1446년 정인지, 신숙주 등을 중심으로 훈민정음의 창제 원리와 사용법을 해설한 책으로, 훈민정음의 제자 원리, 음운체계, 표기례 등을 담고 있습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029857"
#   },
#   {
#     "number": 71,
#     "question": "훈민정음 해례본의 구성은 어떻게 되나요?",
#     "answer": "훈민정음 해례본은 어제서문, 예의, 해례, 정인지 서문으로 구성되며, 예의는 음가와 운용법을, 해례는 제자 원리와 표기법을 상세히 설명합니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065805"
#   },
#   {
#     "number": 72,
#     "question": "훈민정음 해례본의 집필자는 누구인가요?",
#     "answer": "집현전 학자 정인지, 신숙주, 성삼문, 최항, 박팽년, 강희안, 이개, 이선로 등 8인이 집필에 참여했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065805"
#   },
#   {
#     "number": 73,
#     "question": "훈민정음 해례본은 언제 간행되었나요?",
#     "answer": "훈민정음 해례본은 1446년 9월 상한(상순, 초열흘 사이)에 간행되었습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065805"
#   },
#   {
#     "number": 74,
#     "question": "훈민정음 해례본은 어디에서 발견되었나요?",
#     "answer": "1940년경 경북 안동의 고가에서 발견되었고, 현재는 간송미술관이 소장하고 있습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065805"
#   },
#   {
#     "number": 75,
#     "question": "훈민정음 해례본의 서지적 특징은 무엇인가요?",
#     "answer": "전권 33장 1책의 목판본이며, 예의는 4장 7면, 해례는 26장 51면, 정인지 서문은 3장 6면으로 구성되어 있습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065805"
#   },
#   {
#     "number": 76,
#     "question": "해례본의 '예의'는 어떤 내용을 담고 있나요?",
#     "answer": "예의는 훈민정음의 음가 설명, 글자 구조와 표기 방식, 초중종성 배치 및 방점 사용 방법 등을 설명합니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065805"
#   },
#   {
#     "number": 77,
#     "question": "해례본의 '해례'에는 어떤 내용이 담겨 있나요?",
#     "answer": "해례에는 제자 원리, 음운체계, 조음 방식, 자모 분류 및 용례 예시 등 훈민정음의 체계적인 해설이 담겨 있습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065805"
#   },
#   {
#     "number": 78,
#     "question": "해례본의 제자해에서는 무엇을 설명하나요?",
#     "answer": "제자해에서는 자음·모음 제자 원리를 설명하며, 조음위치 상형, 음양오행 이론, 36자모 체계 등 음운 철학이 반영되어 있습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065805"
#   },
#   {
#     "number": 79,
#     "question": "훈민정음의 자음은 어떻게 분류되었나요?",
#     "answer": "자음은 아음, 설음, 순음, 치음, 후음 등으로 분류되며, 각각 오행, 계절, 방위 등과 연계하여 설명됩니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065805"
#   },
#   {
#     "number": 80,
#     "question": "중성 모음자의 제자 원리는 무엇인가요?",
#     "answer": "중성은 천(·), 지(ㅡ), 인(ㅣ)의 삼재 상형에서 출발하며, 각 모음의 깊이와 조음 위치에 따라 초출자와 재출자가 파생되었습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065805"
#   },
#   {
#     "number": 81,
#     "question": "훈민정음 해례본에서 성조는 어떻게 표시하나요?",
#     "answer": "성조는 각 음절의 왼쪽에 방점을 찍어 표기하며, 중세국어의 평성, 상성, 거성, 입성을 구분하는 데 사용됩니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065805"
#   },
#   {
#     "number": 82,
#     "question": "합자해에서는 무엇을 설명하나요?",
#     "answer": "합자해는 초성, 중성, 종성을 결합하여 음절을 구성하는 원리와 병서, 합용 등의 자소 결합법을 설명합니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065805"
#   },
#   {
#     "number": 83,
#     "question": "용자례에서는 어떤 예시가 제공되나요?",
#     "answer": "용자례는 초성, 중성, 종성 각각에 대해 실제 어휘 90단어의 표기례를 들어 훈민정음 사용법을 보여줍니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065805"
#   },
#   {
#     "number": 84,
#     "question": "정인지 서문에는 어떤 내용이 있나요?",
#     "answer": "정인지는 훈민정음 창제 이유, 창제자, 실용성, 간행 연월, 해례본 편찬자 등을 밝히고 있습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065805"
#   },
#   {
#     "number": 85,
#     "question": "훈민정음 해례본에서 강조된 철학적 이론은 무엇인가요?",
#     "answer": "송학 계통의 음양오행, 태극 이론이 훈민정음의 제자 원리에 적용되어 언어 철학적 기반을 이룹니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065805"
#   },
#   {
#     "number": 86,
#     "question": "훈민정음 해례본이 유네스코 세계기록유산에 지정된 이유는?",
#     "answer": "훈민정음 해례본은 독창적인 문자 제정과 함께, 창제 원리·운용법을 체계적으로 기록한 세계 유일의 문서로서 문화사적으로 중요한 가치를 지니기 때문입니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065805"
#   },
#   {
#     "number": 87,
#     "question": "훈민정음 해례본에서 ‘ㆍ’의 의미는 무엇인가요?",
#     "answer": "‘ㆍ’는 하늘을 상징하는 기본모음으로, 깊은 소리를 나타내며, 삼재(천·지·인) 중 '천'을 형상화한 것입니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065805"
#   },
#   {
#     "number": 88,
#     "question": "훈민정음 해례본의 학술적 가치는 무엇인가요?",
#     "answer": "훈민정음 해례본은 문자학, 음운학, 언어철학, 인쇄문화, 조선시대 언어 정책 등 다양한 분야에서 학술적 가치가 뛰어납니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065805"
#   },
#   {
#     "number": 89,
#     "question": "훈민정음 해례본은 왜 '원본'이라 불리나요?",
#     "answer": "훈민정음 해례본은 1446년 간행된 최초의 해설서로, 창제 원리와 목적, 운용법을 가장 완전하게 담고 있어 '원본'으로 불립니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065805"
#   },
#   {
#     "number": 90,
#     "question": "장영실은 누구인가요?",
#     "answer": "장영실은 조선 전기의 대표적인 궁중 기술자로, 물시계 자격루와 옥루, 천문 관측기기 혼천의 등을 제작한 과학자입니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065805"
#   },
#   {
#     "number": 91,
#     "question": "장영실은 어떤 배경에서 태어났나요?",
#     "answer": "장영실은 중국계 귀화인과 기녀 사이에서 태어났으며, 초기에는 동래현의 관노였습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0048697"
#   },
#   {
#     "number": 92,
#     "question": "장영실은 어떻게 등용되었나요?",
#     "answer": "그의 기술적 재능을 알아본 세종에 의해 발탁되어 중국에 파견되었고, 귀국 후 면천된 뒤 상의원별좌로 임명되어 궁중기술자로 활동하게 되었습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0048697"
#   },
#   {
#     "number": 93,
#     "question": "장의원별좌란 무엇인가요?",
#     "answer": "상의원별좌는 궁중 의복 및 기술 관련 업무를 담당하는 관직으로, 장영실은 기술직으로서 이 관직에서 과학기술을 수행했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0048697"
#   },
#   {
#     "number": 94,
#     "question": "장영실이 만든 최초의 물시계는 무엇인가요?",
#     "answer": "1424년 장영실은 경점의 기능을 하는 물시계를 완성했으며, 이는 청동으로 만든 시보 장치였습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0048697"
#   },
#   {
#     "number": 95,
#     "question": "장영실이 제작한 대표적인 물시계는 무엇인가요?",
#     "answer": "1434년 장영실은 김빈과 함께 자동시보장치가 탑재된 물시계 '자격루'를 제작했으며, 이는 그의 대표적인 업적 중 하나입니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0048697"
#   },
#   {
#     "number": 96,
#     "question": "옥루는 어떤 시계인가요?",
#     "answer": "옥루는 장영실이 1438년 제작한 자동 천상시계로, 흠경각에 설치되었으며 중국과 아라비아의 물시계를 철저히 연구하여 만든 독창적 발명품입니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0048697"
#   },
#   {
#     "number": 97,
#     "question": "장영실이 제작한 천문 관측 기기에는 무엇이 있나요?",
#     "answer": "혼천의, 간의, 일성정시의, 규표, 현주일구, 천평일구, 정남일구, 앙부일구 등 다양한 천문·해시계 기구를 제작했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0048697"
#   },
#   {
#     "number": 98,
#     "question": "앙부일구는 어떤 시계인가요?",
#     "answer": "앙부일구는 백성을 위해 제작된 공중 해시계로, 혜정교와 종묘 남쪽 등에 설치된 대표적인 시계입니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0048697"
#   },
#   {
#     "number": 99,
#     "question": "장영실이 갑인자 제작에 어떤 역할을 했나요?",
#     "answer": "장영실은 이천 등과 함께 금속활자인 갑인자를 제작했으며, 조선 인쇄기술의 정점을 이룬 기술자였습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0048697"
#   },
#   {
#     "number": 100,
#     "question": "장영실이 활동하던 시대의 군주는 누구였나요?",
#     "answer": "장영실은 조선의 제4대 왕 세종대왕의 치세에 활동하였습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0048697"
#   },
#   {
#     "number": 101,
#     "question": "장영실은 어떤 계기로 승진했나요?",
#     "answer": "자격루와 옥루 같은 독창적인 과학기구의 제작 공로로 대호군까지 승진했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0048697"
#   },
#   {
#     "number": 102,
#     "question": "장영실이 제작한 기기들은 어디에 설치되었나요?",
#     "answer": "경복궁, 서운관, 흠경각 등 주요 궁중 시설과 관측기관에 설치되었습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0048697"
#   },
#   {
#     "number": 103,
#     "question": "장영실은 어떤 학문이나 기술을 배웠나요?",
#     "answer": "장영실은 중국 파견 경험을 통해 천문학과 시계 제작술을 익혔고, 아라비아 문헌도 참고하여 독창적인 기기를 제작했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0048697"
#   },
#   {
#     "number": 104,
#     "question": "장영실의 과학기술은 어떤 의의를 가지나요?",
#     "answer": "장영실은 조선 초기 과학기술의 르네상스를 이끈 주역으로, 백성을 위한 기술 실현과 국가 주도의 기술 발전에 기여했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0048697"
#   },
#   {
#     "number": 105,
#     "question": "황희는 누구인가요?",
#     "answer": "황희는 조선 전기의 대표적인 명재상으로, 우의정, 좌의정, 영의정부사 등을 역임하며 세종 대의 정치 안정과 문물 진흥에 크게 기여했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0048697"
#   },
#   {
#     "number": 106,
#     "question": "황희의 본관과 자, 호는 무엇인가요?",
#     "answer": "본관은 장수, 자는 구부(懼夫), 호는 방촌(厖村)입니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065420"
#   },
#   {
#     "number": 107,
#     "question": "황희는 어떤 과거 시험을 통과했나요?",
#     "answer": "1383년 사마시, 1385년 진사시, 1389년 문과에 급제하였습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065420"
#   },
#   {
#     "number": 108,
#     "question": "황희는 어떤 사건으로 유배된 적이 있나요?",
#     "answer": "1418년 양녕대군 폐위에 반대했다가 태종의 노여움을 사 교하로 유배되었고, 이후 남원으로 이치되었습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065420"
#   },
#   {
#     "number": 109,
#     "question": "황희는 세종과 어떤 관계였나요?",
#     "answer": "황희는 세종의 최측근 재상으로, 세종의 신뢰를 받으며 영의정으로서 집현전, 예문관, 경연, 춘추관 등을 총괄했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065420"
#   },
#   {
#     "number": 110,
#     "question": "황희는 어떤 성격의 인물이었나요?",
#     "answer": "성품이 너그럽고 청렴하며, 학문과 충효에 뛰어난 인물로 평가됩니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065420"
#   },
#   {
#     "number": 111,
#     "question": "황희는 국가 제도 개혁에 어떤 기여를 했나요?",
#     "answer": "경제육전을 보완하여 현실에 맞게 정비하고, 고려의 예법을 조선의 현실과 명나라 체제에 맞게 수정했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065420"
#   },
#   {
#     "number": 112,
#     "question": "황희는 농업과 의생활에 어떤 정책을 펼쳤나요?",
#     "answer": "곡식 종자 배급과 뽕나무 심기를 장려하여 농업 생산과 의생활을 개선하려 했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065420"
#   },
#   {
#     "number": 113,
#     "question": "황희는 어떤 법제 개혁을 했나요?",
#     "answer": "경제육전을 편찬하면서 원집과 속집의 중복과 누락을 바로잡고 현실에 맞게 보완했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065420"
#   },
#   {
#     "number": 114,
#     "question": "황희가 세종 말기에 한 중요한 역할은 무엇인가요?",
#     "answer": "세종과 유학자들의 내불당 설치를 둘러싼 마찰을 중재하여 정치적 안정을 유지하는 데 기여했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065420"
#   },
#   {
#     "number": 115,
#     "question": "황희는 국방 문제에도 기여했나요?",
#     "answer": "네, 북방 야인과 남방 왜구에 대한 방비책 마련에 참여하며 국방 안정에도 기여했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065420"
#   },
#   {
#     "number": 116,
#     "question": "황희는 어떻게 세종의 신임을 받았나요?",
#     "answer": "세종은 황희를 매일 접견할 정도로 신임했으며, 정무와 문물 정비를 맡기고 중요한 자문을 요청했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065420"
#   },
#   {
#     "number": 117,
#     "question": "황희는 어떤 관직을 가장 오래 수행했나요?",
#     "answer": "1431년부터 1449년까지 18년간 영의정부사를 역임하며 국정을 통리했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065420"
#   },
#   {
#     "number": 118,
#     "question": "황희의 대표적인 시호와 작위는 무엇인가요?",
#     "answer": "시호는 익성(翼成), 작위는 순충보조공신 남원부원군으로 추증되었습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065420"
#   },
#   {
#     "number": 119,
#     "question": "황희는 어떤 문집을 남겼나요?",
#     "answer": "『방촌집』이라는 문집을 남겼습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065420"
#   },
#   {
#     "number": 120,
#     "question": "황희는 어느 지역에서 제향되고 있나요?",
#     "answer": "상주의 옥동서원, 장수의 창계서원에 제향되며, 파주의 반구정에는 영정이 봉안되어 있습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065420"
#   },
#   {
#     "number": 121,
#     "question": "황희는 어떤 형벌 개혁을 주장했나요?",
#     "answer": "천첩의 자손에게 부여되던 천역을 면제하는 등 인권 개선에도 힘썼습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065420"
#   },
#   {
#     "number": 122,
#     "question": "황희가 조선 사회에 남긴 가장 큰 영향은?",
#     "answer": "세종 대 정치의 조화와 안정, 문물 제도의 정비, 유교적 통치의 기틀을 마련한 명재상으로 평가받습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065420"
#   },
#   {
#     "number": 123,
#     "question": "황희는 어떤 정치적 위기를 중재했나요?",
#     "answer": "내불당 설치를 둘러싼 세종과 유생 간 갈등을 중재하여 정치적 균형을 유지했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065420"
#   },
#   {
#     "number": 124,
#     "question": "황희는 어떤 왕에게 배향되었나요?",
#     "answer": "1452년 문종 2년에 세종묘에 배향되었습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065420"
#   },
#   {
#     "number": 125,
#     "question": "성삼문은 누구인가요?",
#     "answer": "성삼문은 조선 세종~세조 대에 활동한 문신으로, 훈민정음 창제에 참여하고 단종 복위를 꾀하다 처형된 사육신 중 한 명입니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0065420"
#   },
#   {
#     "number": 126,
#     "question": "성삼문의 본관, 자, 호는 무엇인가요?",
#     "answer": "본관은 창녕, 자는 근보, 호는 매죽헌입니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029365"
#   },
#   {
#     "number": 127,
#     "question": "성삼문은 어떤 가문 출신인가요?",
#     "answer": "그는 조선 초기의 명문가인 성석용의 후손이며, 아버지는 도총관 성승, 조부는 판중추부사 성달생입니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029365"
#   },
#   {
#     "number": 128,
#     "question": "성삼문은 언제 어떤 시험에 합격했나요?",
#     "answer": "1435년 생원시, 1438년 문과, 1447년 문과 중시에 합격했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029365"
#   },
#   {
#     "number": 129,
#     "question": "성삼문이 훈민정음 창제에 어떤 역할을 했나요?",
#     "answer": "성삼문은 집현전 학사로서 훈민정음 창제 과정에 참여했으며, 자음·모음·운서 정리에 공헌했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029365"
#   },
#   {
#     "number": 130,
#     "question": "성삼문이 요동에 파견된 이유는 무엇인가요?",
#     "answer": "명나라 황찬을 만나 훈민정음의 어음과 자훈을 질정하기 위해 신숙주와 함께 파견되었습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029365"
#   },
#   {
#     "number": 131,
#     "question": "성삼문이 편찬에 참여한 책은 무엇인가요?",
#     "answer": "『동국정운』, 『사성통고』, 『세종실록』, 『병요』 등의 편찬에 참여했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029365"
#   },
#   {
#     "number": 132,
#     "question": "성삼문이 관직에서 어떤 역할을 했나요?",
#     "answer": "집현전 부제학, 예조참의, 사간원 우사간, 좌부승지 등을 지냈습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029365"
#   },
#   {
#     "number": 133,
#     "question": "성삼문은 어떻게 죽게 되었나요?",
#     "answer": "1456년 단종 복위 계획이 발각되어 의금부에서 고문을 받고 능지처참형에 처해졌습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029365"
#   },
#   {
#     "number": 134,
#     "question": "성삼문은 무슨 공신에 녹훈되었나요?",
#     "answer": "계유정난 당시 수충정난공신, 세조 즉위 후 추충좌익공신 3등에 녹훈되었으나 스스로 사양하려 했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029365"
#   },
#   {
#     "number": 135,
#     "question": "사육신에는 누가 포함되나요?",
#     "answer": "성삼문, 박팽년, 이개, 하위지, 유성원, 유응부가 포함됩니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029365"
#   },
#   {
#     "number": 136,
#     "question": "성삼문에 대한 세조의 평가는 무엇인가요?",
#     "answer": "세조는 성삼문을 가리켜 '오늘날은 난신이나 후세에는 충신이다'라고 평했다고 전해집니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029365"
#   },
#   {
#     "number": 137,
#     "question": "성삼문은 신숙주와 어떤 관계였나요?",
#     "answer": "초기에는 훈민정음 업무 등을 함께했지만, 단종 복위 문제로 인해 서로 반대편에 서게 되었습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029365"
#   },
#   {
#     "number": 138,
#     "question": "후대에 성삼문은 어떻게 평가되었나요?",
#     "answer": "숙종 대 이후 충신으로 재평가되어 관작이 회복되었고, 제사를 받게 되었습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029365"
#   },
#   {
#     "number": 139,
#     "question": "성삼문은 어느 지역에서 제향되고 있나요?",
#     "answer": "경북 의성 금학산 아래 사우에서 박팽년 등과 함께 향사되고 있습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029365"
#   },
#   {
#     "number": 140,
#     "question": "성삼문의 시호는 무엇인가요?",
#     "answer": "충문(忠文)이라는 시호가 내려졌습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029365"
#   },
#   {
#     "number": 141,
#     "question": "성삼문이 남긴 저서는 무엇인가요?",
#     "answer": "『매죽헌집』이라는 문집을 남겼습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029365"
#   },
#   {
#     "number": 142,
#     "question": "성삼문이 단종 복위를 계획했다는 증거는 어떻게 드러났나요?",
#     "answer": "김질의 밀고와 세조의 직접 심문을 통해 공모 사실이 밝혀졌습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029365"
#   },
#   {
#     "number": 143,
#     "question": "성삼문에 대한 추모와 복권은 언제 이루어졌나요?",
#     "answer": "1691년 숙종 때 관작이 회복되었고, 사우 건립 및 사액이 이루어졌습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029365"
#   },
#   {
#     "number": 144,
#     "question": "성삼문이 살던 시대의 왕은 누구였나요?",
#     "answer": "세종, 문종, 단종, 세조 시대를 거쳐 활동했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029365"
#   },
#   {
#     "number": 145,
#     "question": "집현전은 어떤 기관인가요?",
#     "answer": "집현전은 조선 세종 대에 궁중에 설치된 학문 연구 기관으로, 인재 양성과 유교 문물 정비, 훈민정음 창제 등 조선 전기 문화 황금기를 이끈 중심 기관입니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0029365"
#   },
#   {
#     "number": 146,
#     "question": "집현전은 언제, 왜 설치되었나요?",
#     "answer": "1420년(세종 2년), 유교 의례와 제도 정비를 위해 필요한 인재 양성과 문풍 진작을 목표로 설치되었습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0055081"
#   },
#   {
#     "number": 147,
#     "question": "집현전 설치 초기의 역할은 무엇이었나요?",
#     "answer": "왕실 교육, 사대 외교문서 작성, 역사 기록, 과거 출제, 왕명 제찬, 풍수 연구 등 다양한 기능을 수행했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0055081"
#   },
#   {
#     "number": 148,
#     "question": "집현전 학사들은 어떤 대우를 받았나요?",
#     "answer": "정무에서 벗어나 독서에 집중할 수 있는 '사가독서'라는 휴가가 주어졌으며, 서적과 연구 환경도 지원받았습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0055081"
#   },
#   {
#     "number": 149,
#     "question": "집현전의 조직 체계는 어떻게 되었나요?",
#     "answer": "부제학 이하가 전임관으로서 실질적인 연구와 행정을 담당했으며, 명예직인 대제학, 제학 등도 포함되어 있었습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0055081"
#   },
#   {
#     "number": 150,
#     "question": "집현전 인원은 얼마나 되었나요?",
#     "answer": "설치 초기에는 10명이었으나 점차 확대되어 최대 32명까지 증가했다가, 1436년 이후에는 20명으로 고정되었습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0055081"
#   },
#   {
#     "number": 151,
#     "question": "집현전 학사가 되기 위한 자격은 무엇이었나요?",
#     "answer": "문사(文士) 출신 중에서도 젊고 재능과 인품이 뛰어난 자가 선발되었습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0055081"
#   },
#   {
#     "number": 152,
#     "question": "집현전의 제1기(1420~1427)의 특징은?",
#     "answer": "학문적 기초를 쌓는 시기로, 다양한 실무 경험과 왕실 교육을 담당하며 집현전의 기반을 다졌습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0055081"
#   },
#   {
#     "number": 153,
#     "question": "집현전의 제2기(1428~1436)는 어떤 시기였나요?",
#     "answer": "의례와 제도의 정비, 유교적 문화 정착을 위한 고제 연구 및 대규모 편찬 사업이 활발히 이루어진 시기입니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0055081"
#   },
#   {
#     "number": 154,
#     "question": "집현전이 편찬한 대표 서적에는 어떤 것들이 있나요?",
#     "answer": "『치평요람』, 『자치통감훈의』, 『정관정요주』, 『효행록』, 『삼강행실』, 『훈민정음 해례』 등이 있습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0055081"
#   },
#   {
#     "number": 155,
#     "question": "훈민정음과 집현전은 어떤 관련이 있나요?",
#     "answer": "집현전은 훈민정음 창제와 해례서 편찬, 언해 작업 등에서 중심적인 역할을 했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0055081"
#   },
#   {
#     "number": 156,
#     "question": "제3기(1437~1455)에는 어떤 변화가 있었나요?",
#     "answer": "정치적 영향력이 강화되며 언론기구화되었고, 첨사원과 서연직을 겸하게 되며 왕정 운영에 더 깊숙이 참여했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0055081"
#   },
#   {
#     "number": 157,
#     "question": "집현전은 왜 폐지되었나요?",
#     "answer": "1456년 사육신의 단종 복위 모의가 집현전 출신 중심으로 일어나자, 세조는 이를 계기로 집현전을 폐지했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0055081"
#   },
#   {
#     "number": 158,
#     "question": "집현전의 후신 기관은 무엇인가요?",
#     "answer": "성종 때 집현전의 후신으로 홍문관이 설치되어 그 전통을 계승했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0055081"
#   },
#   {
#     "number": 159,
#     "question": "집현전은 조선 역사에서 어떤 의미를 가지나요?",
#     "answer": "집현전은 유교 정치를 실현할 학자들을 양성하고, 문화적 기틀을 다져 조선 중기까지 영향을 미친 핵심 지식기관입니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0055081"
#   },
#   {
#     "number": 160,
#     "question": "집현전 학자들에게 주어진 사가독서란 무엇인가요?",
#     "answer": "사가독서는 집현전 학자들에게 일정 기간 정무에서 벗어나 독서와 연구에 전념할 수 있도록 휴가를 주는 제도였습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0055081"
#   },
#   {
#     "number": 161,
#     "question": "세종은 집현전 운영에 어떤 관심을 가졌나요?",
#     "answer": "세종은 집현전을 직접 육성하며, 학문 발전과 제도 정비, 훈민정음 창제 등 주요 국정 과제를 집현전을 통해 실현했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0055081"
#   },
#   {
#     "number": 162,
#     "question": "집현전이 고제 연구에서 맡은 역할은 무엇이었나요?",
#     "answer": "집현전은 중국과 고려의 제도를 연구하여 조선 실정에 맞는 유교적 제도와 의례를 정립하는 데 기여했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0055081"
#   },
#   {
#     "number": 163,
#     "question": "집현전에서 활동한 대표적인 학자들은 누구인가요?",
#     "answer": "성삼문, 신숙주, 박팽년, 정인지, 이개, 최항 등 집현전에서 활동한 학자들은 훈민정음 창제와 다양한 편찬 사업에 기여했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0055081"
#   },
#   {
#     "number": 164,
#     "question": "집현전은 훈민정음 창제 외에 어떤 문화를 발전시켰나요?",
#     "answer": "집현전은 유교 윤리서 편찬, 역사서 정리, 천문·역법 연구 등 조선 초 문물 제도의 정비에 큰 공헌을 했습니다.",
#     "source": "https://encykorea.aks.ac.kr/Article/E0055081"
#   }
# ]

# %%
# 파일에서 읽기
with open('data.json', 'r', encoding='utf-8') as f:
    qa_list = json.load(f)

print(f"✅ 원본 QA 개수: {len(qa_list)}")

# 위 함수 적용
updated = add_source_to_existing_json(qa_list)

print(f"✅ 출처 추가 후 QA 개수: {len(updated)}")

# 저장
with open('qa_with_source.json', 'w', encoding='utf-8') as f:
    json.dump(updated, f, ensure_ascii=False, indent=2)
# Out:
# ✅ 원본 QA 개수: 164
# ✅ 출처 추가 후 QA 개수: 164

# %%
import json
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import itertools

# 1. JSON 데이터 로드
with open('qa_with_source.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

questions = [item["question"] for item in data]

# 2. TF-IDF 벡터화
vectorizer = TfidfVectorizer().fit_transform(questions)
cosine_sim = cosine_similarity(vectorizer)

# 3. 유사도가 높은 쌍 출력 (예: 0.85 이상)
threshold = 0.60
print("유사한 질문 쌍 (유사도 {:.2f} 이상):".format(threshold))
printed = set()

for i, j in itertools.combinations(range(len(questions)), 2):
    sim = cosine_sim[i, j]
    if sim >= threshold:
        pair = tuple(sorted((i, j)))
        if pair not in printed:
            printed.add(pair)
            print(f"[{i+1}] {questions[i]}\n[{j+1}] {questions[j]}\n→ 유사도: {sim:.4f}\n")
# Out:
# 유사한 질문 쌍 (유사도 0.60 이상):
# [34] 4군 6진 개척의 목적은 무엇이었나요?
# [59] 4군 6진 개척의 의의는 무엇인가요?
# → 유사도: 0.6619
#
# [36] 장영실은 어떤 업적을 남겼나요?
# [38] 맹사성은 어떤 업적을 남겼나요?
# → 유사도: 0.6666
#
# [49] 세종 시대의 대표적인 물시계는 무엇인가요?
# [51] 세종 시대의 대표적인 금속활자는 무엇인가요?
# → 유사도: 0.6926
#
# [115] 황희는 어느 지역에서 제향되고 있나요?
# [134] 성삼문은 어느 지역에서 제향되고 있나요?
# → 유사도: 0.8693
#
# [124] 성삼문이 훈민정음 창제에 어떤 역할을 했나요?
# [127] 성삼문이 관직에서 어떤 역할을 했나요?
# → 유사도: 0.6388

# %%
import json

# 기존 JSON 데이터를 불러온다고 가정 (예: data.json에서 로딩)
with open("qa_with_source.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# number 필드 재정렬
for i, item in enumerate(data, start=1):
    item["number"] = i

# 결과 저장 (선택)
with open("qa_with_source.json", "w", encoding="utf-8") as f:
    json.dump(data, f, ensure_ascii=False, indent=2)

# 결과 출력 확인
# print(json.dumps(data[:5], ensure_ascii=False, indent=2))  # 처음 5개만 미리보기

# %%
import os
os.environ["TRANSFORMERS_NO_TF"] = "1"  # TensorFlow 비활성화

from sentence_transformers import SentenceTransformer, util

model = SentenceTransformer("snunlp/KR-SBERT-V40K-klueNLI-augSTS")
from sentence_transformers import SentenceTransformer, util
import itertools

model = SentenceTransformer("snunlp/KR-SBERT-V40K-klueNLI-augSTS")

# 질문만 추출
questions = [item["question"] for item in data]
embeddings = model.encode(questions, convert_to_tensor=True)

# 유사도 계산
pairs = list(itertools.combinations(range(len(questions)), 2))
results = []

for i, j in pairs:
    score = util.cos_sim(embeddings[i], embeddings[j]).item()
    if score > 0.85:
        results.append((i, j, score))

# 유사 질문 출력
for i, j, score in sorted(results, key=lambda x: -x[2]):
    print(f"\n[유사도: {score:.3f}]")
    print(f"Q{i+1}: {questions[i]}")
    print(f"Q{j+1}: {questions[j]}")
# Out:
# [유사도: 0.939]
# Q91: 장영실이 만든 최초의 물시계는 무엇인가요?
# Q92: 장영실이 제작한 대표적인 물시계는 무엇인가요?
#
# [유사도: 0.915]
# Q67: 훈민정음 해례본은 무엇인가요?
# Q71: 훈민정음 해례본은 어디에서 발견되었나요?
#
# [유사도: 0.903]
# Q147: 집현전의 제1기(1420~1427)의 특징은?
# Q148: 집현전의 제2기(1428~1436)는 어떤 시기였나요?
#
# [유사도: 0.898]
# Q70: 훈민정음 해례본은 언제 간행되었나요?
# Q71: 훈민정음 해례본은 어디에서 발견되었나요?
#
# [유사도: 0.894]
# Q34: 4군 6진 개척의 목적은 무엇이었나요?
# Q59: 4군 6진 개척의 의의는 무엇인가요?
#
# [유사도: 0.894]
# Q26: 훈민정음은 언제 창제되고 반포되었나요?
# Q45: 훈민정음은 어떤 배경에서 창제되었나요?
#
# [유사도: 0.889]
# Q67: 훈민정음 해례본은 무엇인가요?
# Q70: 훈민정음 해례본은 언제 간행되었나요?
#
# [유사도: 0.883]
# Q67: 훈민정음 해례본은 무엇인가요?
# Q85: 훈민정음 해례본의 학술적 가치는 무엇인가요?
#
# [유사도: 0.882]
# Q67: 훈민정음 해례본은 무엇인가요?
# Q68: 훈민정음 해례본의 구성은 어떻게 되나요?
#
# [유사도: 0.875]
# Q1: 세종대왕은 어떤 인물인가요?
# Q21: 세종대왕은 몇 대 왕인가요?
#
# [유사도: 0.874]
# Q14: 훈민정음 창제 목적은 무엇인가요?
# Q45: 훈민정음은 어떤 배경에서 창제되었나요?
#
# [유사도: 0.862]
# Q67: 훈민정음 해례본은 무엇인가요?
# Q69: 훈민정음 해례본의 집필자는 누구인가요?
#
# [유사도: 0.862]
# Q48: 앙부일구는 어떤 해시계인가요?
# Q95: 앙부일구는 어떤 시계인가요?
#
# [유사도: 0.855]
# Q23: 세종대왕의 왕비는 누구였나요?
# Q39: 세종대왕은 어떻게 즉위하게 되었나요?
#
# [유사도: 0.854]
# Q106: 황희는 국가 제도 개혁에 어떤 기여를 했나요?
# Q108: 황희는 어떤 법제 개혁을 했나요?
#
# [유사도: 0.852]
# Q1: 세종대왕은 어떤 인물인가요?
# Q23: 세종대왕의 왕비는 누구였나요?

# %%
from collections import defaultdict

clusters = defaultdict(list)
keywords = {
    "훈민정음": ["훈민정음", "해례본"],
    "장영실": ["장영실", "혼천의", "자격루", "천문", "시계"],
    "황희": ["황희"],
    "성삼문": ["성삼문", "사육신"],
    "집현전": ["집현전"],
    "과학기술": ["과학", "기술", "측우기", "도량형", "금속활자"],
    "정치제도": ["정치", "의정부서사제", "육조직계제", "공법"],
    "외교군사": ["여진", "왜구", "4군6진", "대마도", "쓰시마", "정벌"],
}

for item in data:
    assigned = False
    for topic, kws in keywords.items():
        if any(kw in item["question"] for kw in kws):
            clusters[topic].append(item)
            assigned = True
            break
    if not assigned:
        clusters["기타"].append(item)

# 결과 확인
for topic, items in clusters.items():
    print(f"\n[주제: {topic}] - {len(items)}개 문항")
    for i in items:
        print(f"  - {i['question']}")
# Out:
# [주제: 기타] - 48개 문항
#   - 세종대왕은 어떤 인물인가요?
#   - 세종대왕은 어떤 호칭으로 불렸나요?
#   - 세종대왕의 본명과 자는 무엇인가요?
#   - 세종대왕의 즉위 과정은 어땠나요?
#   - 즉위 초기에 세종은 어떤 어려움을 겪었나요?
#   - 세종대왕은 어떤 학문적 특징을 가졌나요?
#   - 세종은 어떤 방식으로 제도를 만들었나요?
#   - 세종대왕은 어떤 역사서를 정비했나요?
#   - 세종 시기에 인쇄술은 어떻게 발전했나요?
#   - 세종은 음악 분야에서도 어떤 업적을 남겼나요?
#   - 세종대왕의 애민정신은 어떻게 나타났나요?
#   - 세종대왕은 어떤 병을 앓았나요?
#   - 세종대왕은 언제 세상을 떠났나요?
#   - 세종대왕은 언제부터 언제까지 재위했나요?
#   - 세종대왕은 몇 대 왕인가요?
#   - 세종대왕의 출생과 사망 연도는?
#   - 세종대왕의 왕비는 누구였나요?
#   - 세종대왕의 능은 어디에 있나요?
#   - 세종대왕이 장려한 한글 문헌에는 어떤 것들이 있나요?
#   - 세종은 음악 분야에서 어떤 조치를 했나요?
#   - 칠정산은 무엇인가요?
#   - 세종대왕이 시행한 조세 제도는?
#   - 세종은 민생 안정에 어떤 노력을 했나요?
#   - 세종대왕의 대외 정책은 무엇이 있었나요?
#   - 4군 6진 개척의 목적은 무엇이었나요?
#   - 맹사성은 어떤 업적을 남겼나요?
#   - 세종대왕은 어떻게 즉위하게 되었나요?
#   - 세종은 유교적 의례 정비에서 어떤 태도를 취했나요?
#   - 세종대의 편찬사업에는 어떤 책들이 있었나요?
#   - 총통등록은 어떤 책인가요?
#   - 농사직설은 어떤 책인가요?
#   - 세종이 편찬한 의약서는 어떤 것이 있나요?
#   - 정간보는 어떤 기보법인가요?
#   - 세종이 작곡한 곡에는 무엇이 있나요?
#   - 세종 시대의 법제 정비 중 대표적인 것은?
#   - 4군 6진 개척의 의의는 무엇인가요?
#   - 세종의 불교 정책은 어땠나요?
#   - 세종은 어떤 인성의 왕이었나요?
#   - 세종은 사료 관리에 어떤 제도를 도입했나요?
#   - 세종의 묘호와 시호는 무엇인가요?
#   - 세종의 업적이 남긴 역사적 의의는?
#   - 세종은 왜 한국사에서 특별히 존경받는 왕인가요?
#   - 중성 모음자의 제자 원리는 무엇인가요?
#   - 합자해에서는 무엇을 설명하나요?
#   - 용자례에서는 어떤 예시가 제공되나요?
#   - 정인지 서문에는 어떤 내용이 있나요?
#   - 장의원별좌란 무엇인가요?
#   - 제3기(1437~1455)에는 어떤 변화가 있었나요?
#
# [주제: 집현전] - 18개 문항
#   - 집현전은 세종대왕 시대에 어떤 역할을 했나요?
#   - 집현전은 어떤 기관인가요?
#   - 집현전은 언제, 왜 설치되었나요?
#   - 집현전 설치 초기의 역할은 무엇이었나요?
#   - 집현전 학사들은 어떤 대우를 받았나요?
#   - 집현전의 조직 체계는 어떻게 되었나요?
#   - 집현전 인원은 얼마나 되었나요?
#   - 집현전 학사가 되기 위한 자격은 무엇이었나요?
#   - 집현전의 제1기(1420~1427)의 특징은?
#   - 집현전의 제2기(1428~1436)는 어떤 시기였나요?
#   - 집현전이 편찬한 대표 서적에는 어떤 것들이 있나요?
#   - 집현전은 왜 폐지되었나요?
#   - 집현전의 후신 기관은 무엇인가요?
#   - 집현전은 조선 역사에서 어떤 의미를 가지나요?
#   - 집현전 학자들에게 주어진 사가독서란 무엇인가요?
#   - 세종은 집현전 운영에 어떤 관심을 가졌나요?
#   - 집현전이 고제 연구에서 맡은 역할은 무엇이었나요?
#   - 집현전에서 활동한 대표적인 학자들은 누구인가요?
#
# [주제: 과학기술] - 4개 문항
#   - 세종대왕이 관심을 가졌던 과학기술은 무엇인가요?
#   - 세종 시기 주요 과학기술 발명품은 무엇인가요?
#   - 세종은 도량형 제도를 어떻게 정비했나요?
#   - 세종 시대의 대표적인 금속활자는 무엇인가요?
#
# [주제: 훈민정음] - 25개 문항
#   - 훈민정음 창제 목적은 무엇인가요?
#   - 훈민정음 창제와 관련된 기록은 왜 적은가요?
#   - 훈민정음 창제에 집현전 학자들이 관여했나요?
#   - 훈민정음은 언제 창제되고 반포되었나요?
#   - 훈민정음은 어떤 배경에서 창제되었나요?
#   - 훈민정음 창제에 참여한 학자들은 누구인가요?
#   - 훈민정음 해례본은 무엇인가요?
#   - 훈민정음 해례본의 구성은 어떻게 되나요?
#   - 훈민정음 해례본의 집필자는 누구인가요?
#   - 훈민정음 해례본은 언제 간행되었나요?
#   - 훈민정음 해례본은 어디에서 발견되었나요?
#   - 훈민정음 해례본의 서지적 특징은 무엇인가요?
#   - 해례본의 '예의'는 어떤 내용을 담고 있나요?
#   - 해례본의 '해례'에는 어떤 내용이 담겨 있나요?
#   - 해례본의 제자해에서는 무엇을 설명하나요?
#   - 훈민정음의 자음은 어떻게 분류되었나요?
#   - 훈민정음 해례본에서 성조는 어떻게 표시하나요?
#   - 훈민정음 해례본에서 강조된 철학적 이론은 무엇인가요?
#   - 훈민정음 해례본이 유네스코 세계기록유산에 지정된 이유는?
#   - 훈민정음 해례본에서 ‘ㆍ’의 의미는 무엇인가요?
#   - 훈민정음 해례본의 학술적 가치는 무엇인가요?
#   - 훈민정음 해례본은 왜 '원본'이라 불리나요?
#   - 성삼문이 훈민정음 창제에 어떤 역할을 했나요?
#   - 훈민정음과 집현전은 어떤 관련이 있나요?
#   - 집현전은 훈민정음 창제 외에 어떤 문화를 발전시켰나요?
#
# [주제: 정치제도] - 6개 문항
#   - 세종은 후반기에 어떤 정치적 조치를 했나요?
#   - 세종은 어떤 정치체제를 실시했나요?
#   - 세종 즉위 초기의 정치 상황은 어땠나요?
#   - 세종은 유교 정치 실현을 위해 어떤 기틀을 마련했나요?
#   - 육조직계제와 의정부서사제의 차이는 무엇인가요?
#   - 공법은 어떤 제도인가요?
#
# [주제: 외교군사] - 2개 문항
#   - 대마도 정벌은 왜 일어났나요?
#   - 세종은 왜 대마도를 정벌했나요?
#
# [주제: 장영실] - 18개 문항
#   - 장영실은 어떤 업적을 남겼나요?
#   - 세종 시대 천문학의 성과는 무엇인가요?
#   - 앙부일구는 어떤 해시계인가요?
#   - 세종 시대의 대표적인 물시계는 무엇인가요?
#   - 장영실은 누구인가요?
#   - 장영실은 어떤 배경에서 태어났나요?
#   - 장영실은 어떻게 등용되었나요?
#   - 장영실이 만든 최초의 물시계는 무엇인가요?
#   - 장영실이 제작한 대표적인 물시계는 무엇인가요?
#   - 옥루는 어떤 시계인가요?
#   - 장영실이 제작한 천문 관측 기기에는 무엇이 있나요?
#   - 앙부일구는 어떤 시계인가요?
#   - 장영실이 갑인자 제작에 어떤 역할을 했나요?
#   - 장영실이 활동하던 시대의 군주는 누구였나요?
#   - 장영실은 어떤 계기로 승진했나요?
#   - 장영실이 제작한 기기들은 어디에 설치되었나요?
#   - 장영실은 어떤 학문이나 기술을 배웠나요?
#   - 장영실의 과학기술은 어떤 의의를 가지나요?
#
# [주제: 황희] - 19개 문항
#   - 황희는 어떤 인물이었나요?
#   - 황희의 본관과 자, 호는 무엇인가요?
#   - 황희는 어떤 과거 시험을 통과했나요?
#   - 황희는 어떤 사건으로 유배된 적이 있나요?
#   - 황희는 세종과 어떤 관계였나요?
#   - 황희는 국가 제도 개혁에 어떤 기여를 했나요?
#   - 황희는 농업과 의생활에 어떤 정책을 펼쳤나요?
#   - 황희는 어떤 법제 개혁을 했나요?
#   - 황희가 세종 말기에 한 중요한 역할은 무엇인가요?
#   - 황희는 국방 문제에도 기여했나요?
#   - 황희는 어떻게 세종의 신임을 받았나요?
#   - 황희는 어떤 관직을 가장 오래 수행했나요?
#   - 황희의 대표적인 시호와 작위는 무엇인가요?
#   - 황희는 어떤 문집을 남겼나요?
#   - 황희는 어느 지역에서 제향되고 있나요?
#   - 황희는 어떤 형벌 개혁을 주장했나요?
#   - 황희가 조선 사회에 남긴 가장 큰 영향은?
#   - 황희는 어떤 정치적 위기를 중재했나요?
#   - 황희는 어떤 왕에게 배향되었나요?
#
# [주제: 성삼문] - 19개 문항
#   - 성삼문은 누구인가요?
#   - 성삼문의 본관, 자, 호는 무엇인가요?
#   - 성삼문은 어떤 가문 출신인가요?
#   - 성삼문은 언제 어떤 시험에 합격했나요?
#   - 성삼문이 요동에 파견된 이유는 무엇인가요?
#   - 성삼문이 편찬에 참여한 책은 무엇인가요?
#   - 성삼문이 관직에서 어떤 역할을 했나요?
#   - 성삼문은 어떻게 죽게 되었나요?
#   - 성삼문은 무슨 공신에 녹훈되었나요?
#   - 사육신에는 누가 포함되나요?
#   - 성삼문에 대한 세조의 평가는 무엇인가요?
#   - 성삼문은 신숙주와 어떤 관계였나요?
#   - 후대에 성삼문은 어떻게 평가되었나요?
#   - 성삼문은 어느 지역에서 제향되고 있나요?
#   - 성삼문의 시호는 무엇인가요?
#   - 성삼문이 남긴 저서는 무엇인가요?
#   - 성삼문이 단종 복위를 계획했다는 증거는 어떻게 드러났나요?
#   - 성삼문에 대한 추모와 복권은 언제 이루어졌나요?
#   - 성삼문이 살던 시대의 왕은 누구였나요?

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# 테스트 후보 모델 목록
model_names = [
    "jhgan/ko-sbert-nli",
    "BM-K/KoSimCSE-roberta",
    "intfloat/multilingual-e5-base"
]

# 테스트용 쿼리와 정답
query = "세종대왕은 어떤 업적을 남겼나요?"
corpus = [
    "Q: 세종대왕은 어떤 인물인가요? A: 조선의 제4대 왕으로 한글을 창제하고...",
    "Q: 훈민정음의 제자 원리는 무엇인가요? A: 상형과 음양오행에 기반하여...",
    "Q: 세종 시대의 과학기술 발명은 무엇인가요? A: 자격루, 혼천의, 측우기 등..."
]
reference_answer = corpus[0]  # 정답 텍스트

# 모델별 유사도 평가
for model_name in model_names:
    print(f"\n🔍 Testing model: {model_name}")
    model = SentenceTransformer(model_name)
    
    query_vec = model.encode([query])
    corpus_vecs = model.encode(corpus)
    
    scores = cosine_similarity(query_vec, corpus_vecs)[0]
    
    # 상위 문장 및 유사도
    for idx, score in enumerate(scores):
        print(f"  → 문장 {idx+1} 유사도: {score:.4f} | {corpus[idx]}")
    
    best_idx = np.argmax(scores)
    print(f"✅ Best match: #{best_idx+1} | Score: {scores[best_idx]:.4f}")
# Out:
# 🔍 Testing model: jhgan/ko-sbert-nli
#   → 문장 1 유사도: 0.7800 | Q: 세종대왕은 어떤 인물인가요? A: 조선의 제4대 왕으로 한글을 창제하고...
#   → 문장 2 유사도: 0.5680 | Q: 훈민정음의 제자 원리는 무엇인가요? A: 상형과 음양오행에 기반하여...
#   → 문장 3 유사도: 0.6642 | Q: 세종 시대의 과학기술 발명은 무엇인가요? A: 자격루, 혼천의, 측우기 등...
# ✅ Best match: #1 | Score: 0.7800
#
# 🔍 Testing model: BM-K/KoSimCSE-roberta
# No sentence-transformers model found with name BM-K/KoSimCSE-roberta. Creating a new one with mean pooling.
#   → 문장 1 유사도: 0.7422 | Q: 세종대왕은 어떤 인물인가요? A: 조선의 제4대 왕으로 한글을 창제하고...
#   → 문장 2 유사도: 0.3908 | Q: 훈민정음의 제자 원리는 무엇인가요? A: 상형과 음양오행에 기반하여...
#   → 문장 3 유사도: 0.6262 | Q: 세종 시대의 과학기술 발명은 무엇인가요? A: 자격루, 혼천의, 측우기 등...
# ✅ Best match: #1 | Score: 0.7422
#
# 🔍 Testing model: intfloat/multilingual-e5-base
#   → 문장 1 유사도: 0.8622 | Q: 세종대왕은 어떤 인물인가요? A: 조선의 제4대 왕으로 한글을 창제하고...
#   → 문장 2 유사도: 0.7571 | Q: 훈민정음의 제자 원리는 무엇인가요? A: 상형과 음양오행에 기반하여...
#   → 문장 3 유사도: 0.8232 | Q: 세종 시대의 과학기술 발명은 무엇인가요? A: 자격루, 혼천의, 측우기 등...
# ✅ Best match: #1 | Score: 0.8622

# %%
from sentence_transformers import SentenceTransformer, util
import torch
"""
    "jhgan/ko-sbert-nli",
    "BM-K/KoSimCSE-roberta",
    "intfloat/multilingual-e5-base",
    "upskyy/bge-m3-korean",
    "jhgan/ko-sroberta-multitask",
    "nlpai-lab/KoE5",
    """
# 테스트할 모델 목록
model_ids = [
    "intfloat/multilingual-e5-base",
    "Qwen/Qwen3-Embedding-0.6B",
    "intfloat/multilingual-e5-large-instruct",
]

# 검증용 질문-답변 세트
qa_pairs = [
    {
        "question": "세종은 정치 권력을 어떻게 분산시키며 유교적 이상을 실현했나요?",
        "answer": "건강상의 이유로 의정부 서사제로 전환하고 세자에게 정무를 위임하여, 권력을 분산시키는 유교적 왕도 정치를 실현했습니다."
    },
    {
        "question": "훈민정음의 제자 원리가 음양오행과 어떤 철학적 관계가 있나요?",
        "answer": "제자해에서는 자음·모음 제자 원리를 설명하며, 조음위치 상형, 음양오행 이론, 36자모 체계 등 음운 철학이 반영되어 있습니다."
    },
    {
        "question": "세종 시대의 천문 기구들은 어떤 원리를 기반으로 제작되었으며, 백성 생활에 어떤 영향을 미쳤나요?",
        "answer": "세종은 혼천의, 정방안, 간의대 등을 설치하고 천문 관측을 체계화했으며, 백성들이 시간을 알 수 있도록 앙부일구와 자격루를 제작하여 일상생활에 도움을 주었습니다."
    }
]

# 유사도 평가
for model_id in model_ids:
    model = SentenceTransformer(model_id)
    print(f"\nTesting model: {model_id}")
    
    for pair in qa_pairs:
        q_vec = model.encode(pair["question"], convert_to_tensor=True)
        a_vec = model.encode(pair["answer"], convert_to_tensor=True)
        similarity = util.cos_sim(q_vec, a_vec).item()
        print(f"  → Q: {pair['question']}\n    A: {pair['answer']}\n    유사도: {similarity:.4f}")
# Out:
# Testing model: intfloat/multilingual-e5-base
#   → Q: 세종은 정치 권력을 어떻게 분산시키며 유교적 이상을 실현했나요?
#     A: 건강상의 이유로 의정부 서사제로 전환하고 세자에게 정무를 위임하여, 권력을 분산시키는 유교적 왕도 정치를 실현했습니다.
#     유사도: 0.8596
#   → Q: 훈민정음의 제자 원리가 음양오행과 어떤 철학적 관계가 있나요?
#     A: 제자해에서는 자음·모음 제자 원리를 설명하며, 조음위치 상형, 음양오행 이론, 36자모 체계 등 음운 철학이 반영되어 있습니다.
#     유사도: 0.8535
#   → Q: 세종 시대의 천문 기구들은 어떤 원리를 기반으로 제작되었으며, 백성 생활에 어떤 영향을 미쳤나요?
#     A: 세종은 혼천의, 정방안, 간의대 등을 설치하고 천문 관측을 체계화했으며, 백성들이 시간을 알 수 있도록 앙부일구와 자격루를 제작하여 일상생활에 도움을 주었습니다.
#     유사도: 0.8743
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/16.3k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/727 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.19G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/9.71k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/313 [00:00<?, ?B/s]
# Testing model: Qwen/Qwen3-Embedding-0.6B
#   → Q: 세종은 정치 권력을 어떻게 분산시키며 유교적 이상을 실현했나요?
#     A: 건강상의 이유로 의정부 서사제로 전환하고 세자에게 정무를 위임하여, 권력을 분산시키는 유교적 왕도 정치를 실현했습니다.
#     유사도: 0.6388
#   → Q: 훈민정음의 제자 원리가 음양오행과 어떤 철학적 관계가 있나요?
#     A: 제자해에서는 자음·모음 제자 원리를 설명하며, 조음위치 상형, 음양오행 이론, 36자모 체계 등 음운 철학이 반영되어 있습니다.
#     유사도: 0.4980
#   → Q: 세종 시대의 천문 기구들은 어떤 원리를 기반으로 제작되었으며, 백성 생활에 어떤 영향을 미쳤나요?
#     A: 세종은 혼천의, 정방안, 간의대 등을 설치하고 천문 관측을 체계화했으며, 백성들이 시간을 알 수 있도록 앙부일구와 자격루를 제작하여 일상생활에 도움을 주었습니다.
#     유사도: 0.6685
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/128 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/140k [00:00<?, ?B/s]
# sentence_xlm-roberta_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/690 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.12G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/271 [00:00<?, ?B/s]
# Testing model: intfloat/multilingual-e5-large-instruct
#   → Q: 세종은 정치 권력을 어떻게 분산시키며 유교적 이상을 실현했나요?
#     A: 건강상의 이유로 의정부 서사제로 전환하고 세자에게 정무를 위임하여, 권력을 분산시키는 유교적 왕도 정치를 실현했습니다.
#     유사도: 0.8951
#   → Q: 훈민정음의 제자 원리가 음양오행과 어떤 철학적 관계가 있나요?
#     A: 제자해에서는 자음·모음 제자 원리를 설명하며, 조음위치 상형, 음양오행 이론, 36자모 체계 등 음운 철학이 반영되어 있습니다.
#     유사도: 0.8978
#   → Q: 세종 시대의 천문 기구들은 어떤 원리를 기반으로 제작되었으며, 백성 생활에 어떤 영향을 미쳤나요?
#     A: 세종은 혼천의, 정방안, 간의대 등을 설치하고 천문 관측을 체계화했으며, 백성들이 시간을 알 수 있도록 앙부일구와 자격루를 제작하여 일상생활에 도움을 주었습니다.
#     유사도: 0.8803

# %%
from sentence_transformers import SentenceTransformer
import faiss
import json
import numpy as np

# 1. JSON 로딩
with open("qa_with_source.json", "r", encoding="utf-8") as f:
    qa_data = json.load(f)

# 2. 질문+답변 텍스트 생성
corpus = [f"Q: {item['question']} A: {item['answer']}" for item in qa_data]

# 3. 임베딩 모델 로딩
model = SentenceTransformer("intfloat/multilingual-e5-base")

# 4. 임베딩 계산
embeddings = model.encode(corpus, show_progress_bar=True, convert_to_numpy=True)
embeddings = embeddings / np.linalg.norm(embeddings, axis=1, keepdims=True)  # 코사인 정규화

# 5. FAISS 인덱스 생성
dimension = embeddings.shape[1]
index = faiss.IndexFlatIP(dimension)
index.add(embeddings)

# 6. 인덱스 및 메타데이터 저장
faiss.write_index(index, "sejong_qa_faiss.index")

metadata = {i: {
    "number": qa_data[i]["number"],
    "question": qa_data[i]["question"],
    "answer": qa_data[i]["answer"]
} for i in range(len(qa_data))}

with open("sejong_qa_metadata.json", "w", encoding="utf-8") as f:
    json.dump(metadata, f, ensure_ascii=False, indent=2)
# Out:
# Batches: 100%|██████████| 5/5 [00:04<00:00,  1.07it/s]

# %%
from sentence_transformers import SentenceTransformer
import faiss
import json
import numpy as np

# 로딩
index = faiss.read_index("sejong_qa_faiss.index")
with open("sejong_qa_metadata.json", "r", encoding="utf-8") as f:
    metadata = json.load(f)

model = SentenceTransformer("intfloat/multilingual-e5-base")

# 검색 함수
def search(query, top_k=3):
    query_embedding = model.encode([query])
    query_embedding = query_embedding / np.linalg.norm(query_embedding, axis=1, keepdims=True)

    D, I = index.search(query_embedding, top_k)
    for rank, idx in enumerate(I[0]):
        result = metadata[str(idx)]
        print(f"\n🔎 TOP {rank+1} (score: {D[0][rank]:.4f})")
        print(f"Q: {result['question']}")
        print(f"A: {result['answer']}")

# 예시 질의
search("세종은 권력을 어떻게 나누었나요?")
# Out:
# 🔎 TOP 1 (score: 0.8606)
# Q: 세종은 어떤 정치체제를 실시했나요?
# A: 세종은 의정부서사제를 시행하여 재상이 정치를 주도하고, 왕은 군사와 인사에 집중하는 방식으로 왕권과 신권의 조화를 이루었습니다.
#
# 🔎 TOP 2 (score: 0.8425)
# Q: 세종대왕의 즉위 과정은 어땠나요?
# A: 세종은 셋째 아들이었지만, 태종이 세자 이제를 폐위하고 충녕대군이었던 세종을 세자로 책봉하며 왕위에 올랐습니다. 태종은 총명하고 학문을 좋아한 세종의 자질을 높이 평가했습니다.
#
# 🔎 TOP 3 (score: 0.8376)
# Q: 세종은 후반기에 어떤 정치적 조치를 했나요?
# A: 건강상의 이유로 의정부 서사제로 전환하고 세자에게 정무를 위임하여, 권력을 분산시키는 유교적 왕도 정치를 실현했습니다.

# %%
# Out:
# 질문: 한글의 창제 원리는 무엇인가요?
# 답변: 짐이 백성의 편리를 도모하고자 하여, 한글을 창제하였도다. 어리석고 지혜로운 이를 불문하고, 모든 백성이 쉽게 글을 읽고 쓸 수 있도록, 한글의 자모를 만들었느니라.
#
# 한글의 창제 원리는, 먼저 말소리와 글자체를 연구하였도다. 우리 백성의 말소리를 바탕으로, 새로운 글자체를 만들었느니라. 한글은十四個의 자모로 구성되었으며, 초성과 중성, 종성을 합하여 하나의 글자를 이루었도다.
#
# 짐이 백성의 편리를 위하여, 한글을 창제하였으니, 백성들이 쉽게 글을 읽고 쓰고, 학문에 뜻을 두어, 지혜를 넓히도록 하였느니라. 이를 위하여, 『훈민정음』을 편찬하였도다. 이 책은 한글의 정체와 소리를 가르치고, 백성들이 쉽게 이해할 수 있도록 하였느니라.
#
# 한글의 창제는, 짐이 백성의 복지를 위하여, 심혈을 기울인 사업이었도다. 백성들이 한글을 익히고, 이를 통해 학문과 지혜를 넓혀, 더好的 삶을 살 수 있도록 하였느니라. 짐이 한글을 창제한 것은, 백성의 애민을 위한 일이니, 후세에까지 전해질 것이라 믿도다.
#
# 질문: 김치의 역사와 문화적 중요성에 대해 설명해주세요.
# 답변: 짐이 김치의 역사와 문화적 중요성을 설명하여 백성們에게 김치의 가치를 널리 알리도록 하겠습니다.
#
# 김치는 우리나라의 전통 음식으로, 신선한 채소와 다양한 양념을 조합하여 만든 발효 음식이니라. 김치의 역사는 우리나라의 역사만큼悠久하여, 삼국 시대 이전부터 김치와 같은 발효 음식을 먹었다는 기록이 있으므로, 김치의 역사도 매우 길¯Â다고 하겠도다.
#
# 김치는 우리나라의 대표적인 식품으로, 각종 채소와 다양한 양념을 사용하여 만든 음식이니라. 김치의 종류는 백김치, 깍두기, 김치전, 오이소박이 등 매우 다양하여, 각 지역과 계절에 따라 다양한 김치를 만들 수 있느니라.
#
# 김치는 단순한 음식이 아니라, 우리나라의 문화와 전통을 상징하는 음식이니라. 김치는 우리의 조상들이 건강하고 맛있는 음식을 만들기 위해 노력한 결과로, 우리나라의 식문화를 대표하는 음식이라고 하겠도다.
#
# 김치는 또한 우리나라의 대표적인 수출 품목으로, 세계 각국에서 우리나라의 김치를 찾는 사람이 많아, 우리나라의 문화를 널리 알리는 데 큰 역할을 하고 있으므로, 짐이 매우 기쁘도다.
#
# 따라서 짐이 백성們에게 김치의 역사와 문화적 중요성을 널리 알리고, 김치를 통해 우리나라의 문화와 전통을 세계에 널리 알리도록 힘쓰도록 하겠습니다. 이를 통해 우리나라의 문화를 널리 알리고, 우리나라의 식문화를 발전시키도록 하겠도다.
#
# 질문: 조선시대의 과거 제도에 대해 간단히 설명해주세요.
# 답변: 짐이 말하도록 하라. 과거 제도란, 조정에서 관직에 임명할 자질이 있는 자를 선발하기 위하여 시행하는 시험이라 하였도다. 이 시험은 주로 문사(文科)와 무사(武科)로 나뉘어 시행되었는데, 문과는 주로 유학에 관한 지식을 시험하고, 무과는 무예와 군사에 관한 지식을 시험하였느니라.
#
# 이 과거 제도는 짐이 조선의 기틀을 닦고, 선비들의 학문과 덕성을 키우기 위해 중요하게 여기었던 제도라 하였도다. 과거 제도를 통해 선발된 관료들은 조정에서 중요한 역할을 하였으며, 백성을 위해 헌신하는 유능한 인재들이라 하였느니라.
#
# 그러나 과거 제도에도 문제점이 있었으니, 시험의 난이도와 부실한 운영 등이 있었던 것이니라. 짐은 이러한 문제점을 개선하고, 과거 제도를 통해 더 많은 인재를 발굴하기 위해 끊임없이 노력하였던 것이니라. 과거 제도가 조선의 발전을 위해 기여하였음은 틀림없도다.

# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[77], line 3
#       1 db = FAISS.load_local(
#       2     "faiss_index",
# ----> 3     HuggingFaceEmbeddings(model_name="intfloat/multilingual-e5-base"),
#       4     allow_dangerous_deserialization=True
#       5 )
#
# File /opt/anaconda3/envs/sl/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:224, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     222     warned = True
#     223     emit_warning()
# --> 224 return wrapped(self, *args, **kwargs)
#
# File /opt/anaconda3/envs/sl/lib/python3.10/site-packages/langchain_community/embeddings/huggingface.py:92, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      86 except ImportError as exc:
#      87     raise ImportError(
#      88         "Could not import sentence_transformers python package. "
#      89         "Please install it with `pip install sentence-transformers`."
#      90     ) from exc
# ---> 92 self.client = sentence_transformers.SentenceTransformer(
#      93     self.model_name, cache_folder=self.cache_folder, **self.model_kwargs
#      94 )
#
# File /opt/anaconda3/envs/sl/lib/python3.10/site-packages/sentence_transformers/SentenceTransformer.py:347, in SentenceTransformer.__init__(self, model_name_or_path, modules, device, prompts, default_prompt_name, similarity_fn_name, cache_folder, trust_remote_code, revision, local_files_only, token, use_auth_token, truncate_dim, model_kwargs, tokenizer_kwargs, config_kwargs, model_card_data, backend)
#     344 except StopIteration:
#     345     pass
# --> 347 self.to(device)
#     348 self.is_hpu_graph_enabled = False
#     350 if self.default_prompt_name is not None and self.default_prompt_name not in self.prompts:
#
# File /opt/anaconda3/envs/sl/lib/python3.10/site-packages/torch/nn/modules/module.py:1343, in Module.to(self, *args, **kwargs)
#    1340         else:
#    1341             raise
# -> 1343 return self._apply(convert)
#
# File /opt/anaconda3/envs/sl/lib/python3.10/site-packages/torch/nn/modules/module.py:903, in Module._apply(self, fn, recurse)
#     901 if recurse:
#     902     for module in self.children():
# --> 903         module._apply(fn)
#     905 def compute_should_use_set_data(tensor, tensor_applied):
#     906     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     907         # If the new tensor has compatible tensor type as the existing tensor,
#     908         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     913         # global flag to let the user control whether they want the future
#     914         # behavior of overwriting the existing tensor or not.
#
# File /opt/anaconda3/envs/sl/lib/python3.10/site-packages/torch/nn/modules/module.py:903, in Module._apply(self, fn, recurse)
#     901 if recurse:
#     902     for module in self.children():
# --> 903         module._apply(fn)
#     905 def compute_should_use_set_data(tensor, tensor_applied):
#     906     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     907         # If the new tensor has compatible tensor type as the existing tensor,
#     908         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     913         # global flag to let the user control whether they want the future
#     914         # behavior of overwriting the existing tensor or not.
#
#     [... skipping similar frames: Module._apply at line 903 (1 times)]
#
# File /opt/anaconda3/envs/sl/lib/python3.10/site-packages/torch/nn/modules/module.py:903, in Module._apply(self, fn, recurse)
#     901 if recurse:
#     902     for module in self.children():
# --> 903         module._apply(fn)
#     905 def compute_should_use_set_data(tensor, tensor_applied):
#     906     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     907         # If the new tensor has compatible tensor type as the existing tensor,
#     908         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     913         # global flag to let the user control whether they want the future
#     914         # behavior of overwriting the existing tensor or not.
#
# File /opt/anaconda3/envs/sl/lib/python3.10/site-packages/torch/nn/modules/module.py:930, in Module._apply(self, fn, recurse)
#     926 # Tensors stored in modules are graph leaves, and we don't want to
#     927 # track autograd history of `param_applied`, so we have to use
#     928 # `with torch.no_grad():`
#     929 with torch.no_grad():
# --> 930     param_applied = fn(param)
#     931 p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     933 # subclasses may have multiple child tensors so we need to use swap_tensors
#
# File /opt/anaconda3/envs/sl/lib/python3.10/site-packages/torch/nn/modules/module.py:1329, in Module.to.<locals>.convert(t)
#    1322     if convert_to_format is not None and t.dim() in (4, 5):
#    1323         return t.to(
#    1324             device,
#    1325             dtype if t.is_floating_point() or t.is_complex() else None,
#    1326             non_blocking,
#    1327             memory_format=convert_to_format,
#    1328         )
# -> 1329     return t.to(
#    1330         device,
#    1331         dtype if t.is_floating_point() or t.is_complex() else None,
#    1332         non_blocking,
#    1333     )
#    1334 except NotImplementedError as e:
#    1335     if str(e) == "Cannot copy out of meta tensor; no data!":
#
# RuntimeError: MPS backend out of memory (MPS allocated: 17.80 GB, other allocations: 2.98 MB, max allowed: 18.13 GB). Tried to allocate 732.43 MB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).

# %%
# Out:
# 짐은 학문과 독서를甚은 즐겨 하였도다. 특히 역사와 천문학, 음악 등에 큰 관심을 가졌으며, 백성들의 삶을 улучш하기 위한 과학기술에도 많은 관심을 두었느니라. 이에 대해 더 알고 싶은 것이 있는가?
